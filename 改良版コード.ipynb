# %%
#宮嶋櫂と栗林輝による
graph = {
    #1階
    '職員室':{'職員室前':0.5},
    '職員室前':{'校長室':2.5,'IBセンター前':1,'事務室前':5, '職員室': 0.5},
    '校長室':{'職員室前':2.5},
    'IBセンター前':{'職員室前':1,'IBセンター':1},
    'IBセンター':{'IBセンター前':1},
    '1F階段1前':{'1F階段1':1},
    '1F階段1':{'1F階段1前':1, '2F階段1': 3},
    '会議室前':{'会議室1・2・3':1,'会議室4':1,'国語ゾーン0':2},
    '会議室1・2・3':{'会議室前':1},
    '会議室4':{'会議室前':1},
    '国語ゾーン0':{'会議室前':1,'国語ゾーン1':2,'トイレ国語ゾーン':1},
    'トイレ国語ゾーン':{'国語ゾーン0':1},
    '国語ゾーン1':{'国語1':1,'国語7':1, '国語ゾーン0': 2, '国語ゾーン2': 2},
    '国語1':{'国語ゾーン1':1},
    '国語7':{'国語ゾーン1':1},
    '国語ゾーン2':{'国語ゾーン1':2,'国語2':1,'国語ゾーン3':2},
    '国語2':{'国語ゾーン2':1},
    '国語ゾーン3':{'国語3':1,'国語ラウンジ':2,'国語ゾーン2':2,'国語ゾーン4':2},
    '国語3':{'国語ゾーン3':1},
    '国語ラウンジ':{'国語ゾーン3':2},
    '国語ゾーン4':{'国語ゾーン3':2,'国語4':1,'国語センター':1,'1F階段2前':2},
    '1F階段2前':{'1F階段2':1,'国語5':2,'国語ゾーン6':2, '国語ゾーン4': 2},
    '1F階段2':{'1F階段2前':1,'2F階段2':3},
    '国語4':{'国語ゾーン4':1},
    '国語5':{'1F階段2前':2},
    '国語ゾーン6':{'国語6':1,'1F階段2前':1,'国語センター':1,'国社ゼミ室前':2},
    '国語6':{'国語ゾーン6':1},
    '国語センター':{'国語ゾーン6':1,'国語ゾーン4':1},
    '国社ゼミ室前':{'国語ゼミ室':1,'社会ゼミ室':1,'社会6':1,'社会ゾーン7':2, '国語ゾーン6':2},
    '国語ゼミ室':{'国社ゼミ室前':1},
    '社会ゼミ室':{'国社ゼミ室前':1},
    '社会6':{'国社ゼミ室前':1},
    '社会ゾーン7':{'トイレ社会ゾーン':1,'社会7':1,'社会ゾーン5':2, '国社ゼミ室前':2},
    'トイレ社会ゾーン':{'社会ゾーン7':1},
    '社会7':{'社会ゾーン7':1},
    '社会ゾーン5':{'社会ゾーン7':2,'社会5':1,'社会ラウンジ':2,'社会ゾーン4':2},
    '社会5':{'社会ゾーン5':1},
    '社会ゾーン4':{'社会ゾーン5':2,'社会4':1,'社会ラウンジ':1.5,'1F階段3前':1},
    '社会4':{'社会ゾーン4':1},
    '1F階段3前':{'社会3':2,'1F階段3':1,'社会ゾーン2':1, '社会ゾーン4':1},
    '社会3':{'1F階段3前':2},
    '1F階段3':{'1F階段3前':1,'2F階段3':3},
    '社会ゾーン2':{'1F階段3前':2,'社会2':1,'社会ラウンジ':3,'社会ゾーン1':2},
    '社会ラウンジ':{'社会ゾーン5':2,'社会ゾーン4':1.5,'社会ゾーン2':3},
    '社会2':{'社会ゾーン2':1},
    '社会ゾーン1':{'社会センター':1,'社会1':1,'職員用トイレ前':4, '社会ゾーン2':2},
    '職員用トイレ前':{'職員用トイレ':1,'社会ゾーン1':4,'保健室前':2},
    '社会センター':{'社会ゾーン1':1},
    '社会1':{'社会ゾーン1':1},
    '職員用トイレ':{'職員用トイレ前':1},
    '保健室前':{'保健室':1,'カウンセリングルーム前':1, '職員用トイレ前':2},
    '保健室':{'保健室前':1},
    'カウンセリングルーム前':{'カウンセリングルーム':1,'相談室前':1, '保健室前': 1},
    'カウンセリングルーム':{'カウンセリングルーム前':1},
    '相談室前':{'相談室1・2':1,'カフェラウンジ前':2, 'カウンセリングルーム前':1},
    '相談室1・2':{'相談室前':1},
    'カフェラウンジ前':{'相談室前':2,'カフェラウンジ':1,'玄関前':2},
    'カフェラウンジ':{'カフェラウンジ前':1},
    '玄関前':{'カフェラウンジ前':2,'1F大階段前':1},
    '1F大階段前':{'玄関前':1,'1F大階段':1,'事務室前':5},
    '1F大階段':{'1F大階段前':1,'2F大階段':5},
    '事務室前':{'1F大階段前':5,'職員室前':5,'事務室':2,'1Fエレベーター':2,'中庭':5},
    '事務室':{'事務室前':2},
    '1Fエレベーター':{'事務室前':2,'2Fエレベーター':4},
    #①中庭の追加
    '中庭':{'事務室前':5},
    #2階　宮嶋櫂作成
    'ピロティ': {'下り階段': 7},
    '下り階段': {'体育館': 3,'ピロティ': 7},
    '体育館': {'保健体育センター': 0.5, '体育館前': 3, '下り階段': 3},
    '保健体育センター': {'体育館': 0.5},
    '体育館前': {'体育館': 3, 'スロープ': 2},
    'スロープ': {'体育館前': 2, 'トイレPHゾーン': 0.5, '階段': 4},
    'トイレPHゾーン': {'スロープ': 0.5},
    '階段': {'スロープ': 4, '格技室': 2, 'PHゾーン': 6},
    '格技室': {'階段': 2},
    'PHゾーン': {'階段': 6, 'PHゾーン入口': 7},
    'PHゾーン入口': {'PHゾーン': 7, '生徒会室前': 3, '2Fエレベーター前': 1},
    '2Fエレベーター前': {'PHゾーン入口': 1, '2Fメディアセンター前': 2, '2Fエレベーター': 0.5},
    '2Fエレベーター': {'2Fエレベーター前': 0.5,'1Fエレベーター':4},    #エレベーター
    '2Fメディアセンター前': {'2Fエレベーター前': 2, '2F大階段': 3, '2Fメディアセンター': 1, 'カフェラウンジ吹き抜け': 4},
    '2F大階段': {'2Fメディアセンター前': 3,'1F大階段':5,'3F大階段':5},                  #大階段
    '2Fメディアセンター': {'2Fメディアセンター前': 1, '2F階段メディアセンター内': 2},
    '2F階段メディアセンター内': {'2Fメディアセンター': 2,'3F階段メディアセンター内':4},         #メディアセンターの中の階段
    'カフェラウンジ吹き抜け': {'理科ゾーン6': 8, '2Fメディアセンター前': 4},
    '理科ゾーン6': {'カフェラウンジ吹き抜け': 8, '実験室6': 1, '理科ゾーン1': 2},
    '実験室6': {'理科ゾーン6': 1},
    '理科ゾーン1': {'理科ゾーン6': 2, '実験室1': 1, '2F物品庫2': 1, '理科ゾーン5': 2},
    '実験室1': {'理科ゾーン1': 1},
    '2F物品庫2': {'理科ゾーン1': 1},
    '理科ゾーン5': {'理科ゾーン1': 2, '実験室5': 1, '理科センター前': 1},
    '実験室5': {'理科ゾーン5': 1},
    '理科センター前': {'理科ゾーン5': 1, '理科センター': 0.2, '理科ゾーン4': 1},
    '理科センター': {'理科センター前': 0.2},
    '理科ゾーン4': {'理科センター前': 1, '実験室4': 1, '理科ゾーン2': 2},
    '実験室4': {'理科ゾーン4': 1},
    '理科ゾーン2': {'理科ゾーン4': 2, '実験室2': 1, '2F物品庫1': 1, '理科研究室2前': 1},
    '実験室2': {'理科ゾーン2': 1},
    '2F物品庫1': {'理科ゾーン2': 1},
    '理科研究室2前': {'理科ゾーン2': 1, '理科研究室2': 1, '2F階段3前': 1},
    '理科研究室2': {'理科研究室2前': 1},
    '2F階段3前': {'理科研究室2前': 1, '2F階段3': 1, '理科研究室1前': 1, '理科教室前1': 1},
    '2F階段3': {'2F階段3前': 1,'1F階段3':3,'3F階段3':3},                    #階段3(社会ゾーン - 理科ゾーン - 美術室方面に行く階段)
    '理科研究室1前': {'理科研究室1': 0.5, '理科ゼミ室': 0.5, '2F階段3前': 1},
    '理科ゼミ室': {'理科研究室1前': 0.5},
    '理科研究室1': {'理科研究室1前': 0.5},
    '理科教室前1': {'2F階段3前': 1, '理科1': 1, '理科教室前2': 2},
    '理科1': {'理科教室前1': 1},
    '理科教室前2': {'理科教室前1': 2, '理科2': 1, '実験室3': 1, '2Fトイレ前': 2},
    '理科2': {'理科教室前2': 2},
    '2Fトイレ前': {'理科教室前2': 2, '実験室3': 1, 'トイレ理科ゾーン': 1, '数学ゾーン9': 2},
    '実験室3': {'理科教室前2': 1, '2Fトイレ前': 1},
    'トイレ理科ゾーン': {'2Fトイレ前': 1},
    '数学ゾーン9': {'2Fトイレ前': 2, '数学9': 1, '数学ラウンジ2': 2, '数学ゾーン8': 2},
    '数学9': {'数学ゾーン9': 1},
    '数学8': {'数学ゾーン8': 1},
    '数学ゾーン8': {'数学ゾーン9': 2, '数学8': 1, '数学ラウンジ2': 2, '2F階段2前': 1},
    '2F階段2前': {'数学ゾーン8': 1, '数学ゼミ室1前': 0.5, '2F階段2': 1, '数学ゾーン7': 2},
    '数学ゼミ室1前': {'2F階段2前': 0.5, '数学ゼミ室1': 1},
    '数学ゼミ室1': {'数学ゼミ室1前': 1},
    '2F階段2': {'2F階段2前': 1,'1F階段2':3,'3F階段2':3},                      #階段2(国語ゾーン - 数学ゾーン - Call教室に行く階段)
    '数学ゾーン7': {'2F階段2前': 2, '数学ラウンジ2': 2, '数学7': 1, '数学センター前': 2},
    '数学ラウンジ2': {'数学ゾーン9': 2, '数学ゾーン8': 2, '数学ゾーン7': 2},
    '数学7': {'数学ゾーン7': 1},
    '数学センター前': {'数学ゾーン7': 2, '数学センター': 1, '数学6': 1, '数学ゾーン5': 2},
    '数学センター': {'数学センター前': 1},
    '数学6': {'数学センター前': 1},
    '数学ゾーン5': {'数学センター前': 2, '数学5': 1, '数学ゾーン4': 2},
    '数学5': {'数学ゾーン5': 1},
    '数学ゾーン4': {'数学ゾーン5': 2, '数学4': 1, '数学ラウンジ1': 1, '数学ゾーン3': 2},
    '数学4': {'数学ゾーン4': 1},
    '数学ゾーン3': {'数学ゾーン4': 2, '数学ラウンジ1': 1, '数学3': 1, '数学ゾーン2': 2},
    '数学ラウンジ1': {'数学ゾーン4': 1, '数学ゾーン3': 1},
    '数学3': {'数学ゾーン3': 1},
    '数学ゾーン2': {'数学ゾーン3': 2, 'トイレ数学ゾーン': 1, '数学2': 1, '2F階段1前': 2},
    'トイレ数学ゾーン': {'数学ゾーン2': 1},
    '数学2': {'数学ゾーン2': 1},
    '2F階段1前': {'数学ゾーン2': 2, '2F階段1': 1, '数学ゼミ室2': 1, '数学ゾーン1': 2},
    '数学ゼミ室2': {'2F階段1前': 1},
    '2F階段1': {'2F階段1前': 1,'1F階段1':3,'3F階段1':3},
    '数学ゾーン1': {'2F階段1前': 2, '数学1': 1, '生徒会室前': 2},
    '数学1': {'数学ゾーン1': 1},
    '生徒会室前': {'PHゾーン入口': 3, '数学ゾーン1': 2, '生徒会室': 1, '多目的ホール前': 2},
    '生徒会室': {'生徒会室前': 1},
    '多目的ホール前': {'生徒会室前': 2, '新聞局': 1, '多目的ホール入口': 2},
    '新聞局': {'多目的ホール前': 1},
    '多目的ホール入口': {'多目的ホール前': 2, '放送室': 1, '多目的ホール': 2},
    '放送室': {'多目的ホール入口': 1},
    '多目的ホール': {'多目的ホール入口': 2},
    #3階
    '3F階段メディアセンター内':{'2F階段メディアセンター内':4,'3Fメディアセンター':2},
    '3Fメディアセンター':{'3F階段メディアセンター内':2,'3Fメディアセンター前':1},
    '3Fメディアセンター前':{'廊下':4,'3F大階段前':2, '3Fメディアセンター':1},
    '3F大階段前':{'3Fメディアセンター前':2,'3F大階段':1,'キャリアセンター前':2},
    '3F大階段':{'3F大階段前':1,'2F大階段':5},
    'キャリアセンター前':{'3F大階段前':2,'キャリアセンター':1,'英語ゾーン2':3},
    'キャリアセンター':{'キャリアセンター前':1},
    '英語ゾーン2':{'キャリアセンター前':3,'英語ゾーン3':2,'英語2':1,'英語ゾーン1':2},
    '英語ゾーン1':{'英語ゾーン2':2,'英語ラウンジ1':1,'英語1':1},
    '英語ラウンジ1':{'英語ゾーン1':1},
    '英語1':{'英語ゾーン1':1},
    '英語2':{'英語ゾーン2':1},
    '英語ゾーン3':{'英語ゾーン2':2,'英語ラウンジ2':1,'英語3':1,'3F階段1前':1},
    '英語ラウンジ2':{'英語ゾーン3':1},
    '英語3':{'英語ゾーン3':1},
    '3F階段1前':{'英語ゾーン3':1,'英語ゾーン4':1,'3F階段1':1},
    '3F階段1':{'3F階段1前':1,'2F階段1':3},
    '英語ゾーン4':{'3F階段1前':1,'トイレ音楽室横':1,'英語4':1,'英語ゾーン5':4},
    'トイレ音楽室横':{'英語ゾーン4':1},
    '英語4':{'英語ゾーン4':1},
    '英語ゾーン5':{'英語ゾーン4':4,'英語5':1,'英語ラウンジ3':2,'英語ゾーン6':2},
    '英語5':{'英語ゾーン5':1},
    '英語ゾーン6':{'英語ゾーン5':2,'英語6':1,'英語ラウンジ3':2,'英語ゾーン7':2},
    '英語ラウンジ3':{'英語ゾーン5':2,'英語ゾーン6':2},
    '英語6':{'英語ゾーン6':1},
    '英語ゾーン7':{'英語ゾーン6':2,'英語センター':1,'英語7':1,'英語ゾーン8':2},
    '英語センター':{'英語ゾーン7':1},
    '英語7':{'英語ゾーン7':1},
    '英語ゾーン8':{'英語ゾーン7':2,'英語8':1,'3F階段2前':2},
    '英語8':{'英語ゾーン8':1},
    '3F階段2前':{'英語ゾーン8':2,'英語ゼミ室1前':0.5,'3F階段2':1,'CALL教室前':2},
    '3F階段2':{'3F階段2前':1,'2F階段2':3},
    '英語ゼミ室1前':{'3F階段2前':0.5,'英語ゼミ室1':1},
    '英語ゼミ室1':{'英語ゼミ室1前':1},
    'CALL教室前':{'3F階段2前':2,'CALL教室':1,'英語ゼミ室2前':3},
    'CALL教室':{'CALL教室前':1},
    '英語ゼミ室2前':{'CALL教室前':3,'英語ゼミ室2':1,'トイレ英語ゾーン前':1},
    '英語ゼミ室2':{'英語ゼミ室2前':1},
    'トイレ英語ゾーン前':{'トイレ英語ゾーン':1,'英語ゼミ室2前':1,'音楽室前':4},
    'トイレ英語ゾーン':{'トイレ英語ゾーン前': 1},
    '音楽室前':{'トイレ英語ゾーン前':4,'音楽室':1,'3F階段3前':3},
    '音楽室':{'音楽室前':1},
    '3F階段3前':{'3F階段3':0.5,'音楽準備室':1,'音楽室前':3,'美術室前':2},
    '音楽準備室':{'3F階段3前':1},
    '3F階段3':{'3F階段3前':0.5,'2F階段3':3},
    '美術室前':{'美術室':1,'3F物品庫1':1,'ATセンター前':1, '3F階段3前':2},
    '3F物品庫1':{'美術室前':1},
    '美術室':{'美術室前':1},
    'ATセンター前':{'美術室前':1,'ATセンター':1,'被服室前':3},
    'ATセンター':{'ATセンター前':1},
    '被服室前':{'木工造形室':1,'被服室':1,'廊下2':1, 'ATセンター前': 3},
    '木工造形室':{'被服室前':1},
    '被服室':{'被服室前':1},
    '廊下2':{'3F物品庫2':1,'調理室前':1,'被服室前':1},
    '3F物品庫2':{'廊下2':1},
    '調理室前':{'機械室':1,'調理室':1,'廊下2':1,'コンピュータ室前':3},
    '機械室':{'調理室前':1},
    '調理室':{'調理室前':1},
    'コンピュータ室前':{'コンピュータ室':1,'調理室前':3,'金工造形室':1,'廊下3':3},
    '金工造形室':{'コンピュータ室前':1},
    '廊下3':{'3F物品庫3':0.5,'書道室':1,'廊下':2,'コンピュータ室前':3},
    '書道室':{'廊下3':1},
    '3F物品庫3':{'廊下3':1},
    '廊下':{'廊下3':2,'3Fメディアセンター前':4},
    'コンピュータ室':{'コンピュータ室前':1},
    }

#④教室名の表示
print("教室名一覧")
for output in graph:
  print(output)
print()

distance = {key: float('inf') for key in graph.keys()}
check = {key: False for key in graph.keys()}
ans = {key: None for key in graph.keys()}

#⑤移動時間の表示
def dijkstra(start_node, goal_node):
    for node in distance:
        distance[node] = float('inf')
    distance[start_node] = 0
    check[start_node] = True
    previous = start_node

    while check[goal_node] == False:
        for neighbor, dist in graph[previous].items():
            if distance[neighbor] > distance[previous] + dist:
                distance[neighbor] = distance[previous] + dist
                ans[neighbor] = previous

        min_distance = float('inf')
        for node, dist in distance.items():
            if not check[node] and dist < min_distance:
                min_distance = dist
                next_previous = node

        previous = next_previous
        check[previous] = True

    print(f"最短経路の距離の合計: {distance[goal_node]}")

#栗林輝作成
def printAns():
    printAnsItem = ans[start]
    while True:
      if printAnsItem == None:
        break
      else:
        print(printAnsItem)
        printAnsItem = ans[printAnsItem]


#宮嶋櫂作成、栗林輝編集
while True:
  print("走れ！")
  global start, goal
  print("スタート地点を入力してください。")
  start = input()
  if start in graph:
    print(f"'{start}' ですね。了解です。")
    break
  else:
    print(f"おっと。'{start}' は存在しません。もう一度入力してください。")
while True:
  print("目的地を入力してください。")
  goal = input()
  if goal in graph and goal != start:
    print(f"'{goal}' ですね。了解です。最短経路を検索します...")
    break
  elif goal == start:
    print("おっと。スタート地点と目的地が同じです。もう一度入力してください。")
  else:
    print(f"おっと。'{goal}' は存在しません。もう一度入力してください。")

dijkstra(goal,start)

#③出力の修正
while True:
  print("別の選択肢を表示しますか？")
  goal = str(input("YES or NO"))
  if goal == "YES":
    print("別のルートは表示できません。自分で探してください")
    break
  if goal == "NO":
    print("了解しました")
    break
  if goal != "YES" and goal != "NO":
    print("YESもしくはNOで入力してください。")

while True:
  more=(input("もう一度経路を探索しますか？"))
  if more != "YES" and more != "NO":
    print("YESもしくはNOで入力してください。")
  if more == "NO":
    stop=["機能を","停止","します"]
    for w in stop:
      print(w)
    break
  if more == "YES":
    print("もう一度実行ボタンを押して下さい")
    break
